# %% [markdown]
# welcome to your first notebook

# %% [markdown]
# lesson1: variables

# %% [markdown]
# define 4 variables in fourdifferent types

# %%
x=1
X=2
name='ahmad'
GPA=3.2
is_jordanian=True

# %% [markdown]
# print the type of each variable:

# %%
print(type(is_jordanian))
print(type(x))
print(type(GPA))
print(type(name))
# Out:
# <class 'bool'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# print the value of each variable

# %%
print(x)
print(name)
print(GPA)
print(is_jordanian)
# Out:
# 1
# ahmad
# 3.2
# True

# %%
z=0
print(x)
print(z)
print(x+GPA)
print(name)
print(x)
print()
# Out:
# 1
# 0
# 4.2
# ahmad
# 1
# <function print>

# %% [markdown]
# Print:
#
# print(‘’)
# print (“ ”)
# print (10)
# print (x)
# print (‘*’ * 10)
# print (‘’+’’)

# %%
print(5)
print(5*2)
# Out:
# 5
# 10

# %%
print('hello word')
print('2588gdgefede?????>>     @#%')
# Out:
# hello word
# 2588gdgefede?????>>     @#%

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
print(x)
# Out:
# 1

# %%
print(x+z*5)
# Out:
# 1

# %%
print('Mona'+ ' ' + 'Qasem')
# Out:
# Mona Qasem

# %%
name="What's your name"

# %%
print('*'*10)
# Out:
# **********

# %% [markdown]
# ## write a code that combines a user's name with "@gmail.com" to create an acoount and print the result
#
# define the name
#
# add the "@gmail.com" and store it in a variable named account
#
# print the result

# %%
name='mona'
account=name+'@gmail.com'
print(account)
# Out:
# mona@gmail.com

# %% [markdown]
# Objectives:
#
#
# Receive input
#
# Type conversion
#
# Strings
#
# Formatted Strings
#
# String Methods

# %%
a=input()
# Out:
# 1

# %%
print(a)
# Out:
# 1

# %%
# convert units
kg=int(input('please enter weight in Kg '))
lbs=kg*2.2
print(lbs)
# Out:
# please enter weight in Kg 50
# 110.00000000000001

# %% [markdown]
# task1
#
# Task: ask the user two questions, about their name and age the print a customized message
#
#
# E.g.    Mona is 26 years old
#
#
# name +  "is " + age + " years old"

# %%
name= input('enter name ')
age=input('enter age ')
print(name+ " is " + age + " years old")
# Out:
# enter name ahmad
# enter age 25
# ahmad is 25 years old

# %% [markdown]
# task 2
#
# Welcome mona, you are 27 years old
#
# You were born in 1994

# %%
year_of_birth=2022-int(age)
print("you were born in"+ str(year_of_birth))
# Out:
# you were born in 1997

# %% [markdown]
# task 3
#
# Ask the user for their birth year, then calculate their age and print the result as such:
#
# Mona is 26 years old
#
# 1) year of birth input
#
# 2) int , calcucate age
#
# 3) age --> str "      "

# %%
name= input('enter name ')
y=input('enter year ')
age=2022-int(y)
print("you are"+ str(age)+ ' years old')

# %% [markdown]
# arithmatic operations

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
10%3
# Out:
# 1

# %%
10**2
# Out:
# 100

# %%
c=0
c=c+1
c+=1
a*=3
b=a*3

# %% [markdown]
# built in math function

# %%
round(3.7)
# Out:
# 4

# %%
abs(-5)
# Out:
# 5

# %% [markdown]
# module

# %%
import math
math.sin(0)
# Out:
# 0.0

# %%
True and False
# Out:
# False

# %% [markdown]
# strings

# %%
msg='welcome to Python'
msg[0:7]
msg[-6:]
# Out:
# 'Python'

# %%
msg[:]
# Out:
# 'welcome to Python'

# %%
msg
# Out:
# 'welcome to Python'

# %%
msg[0]
# Out:
# 'w'

# %%
msg[4]
# Out:
# 'o'

# %%
msg[0:5]

# %%
print(a)
# Out:
# welco

# %% [markdown]
# srting method
#
# function : general purpose
#
# method : object oriented

# %%
upper(msg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-ae1899867693> in <module>()
# ----> 1 upper(msg)
#
# NameError: name 'upper' is not defined

# %%
msg.upper()
# Out:
# 'WELCOME TO PYTHON'

# %%
upper()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-79052b194996> in <module>()
# ----> 1 upper()
#
# NameError: name 'upper' is not defined

# %%
x=1
x.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-5be9e3dca3a7> in <module>()
#       1 x=1
# ----> 2 x.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %%
msg.find()
# Out:
# 4

# %%
a=msg.replace('o','0')

# %%
msg.replace()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-f84846347503> in <module>()
# ----> 1 replace()
#
# NameError: name 'replace' is not defined

# %%
print(msg)
print(a)
# Out:
# welcome to Python
# welc0me t0 Pyth0n

# %%
len(msg)
'o' in msg
msg.find('o')
# Out:
# True
